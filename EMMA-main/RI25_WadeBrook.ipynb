# %% [markdown]
# ## Notebook to run pca-emma python module for winter events from Wade Brook in 2025

# %%
import sys
sys.path.append("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/")

#from EMMA.event-pca import plot_emma_fractions_with_hydrograph
from EMMA.event-pca-error-bars import plot_event_pca_with_avgEM
#from emma.pca import plot_event_pca
# Out:
#   Cell In[1], line 5
#     from EMMA.event-pca-error-bars import plot_event_pca_with_avgEM
#                    ^
# SyntaxError: invalid syntax
